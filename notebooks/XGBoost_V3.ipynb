# %%
import pandas as pd
import numpy as np
import numpy as np
import statsmodels.api as sm
import warnings
import itertools
warnings.filterwarnings("ignore")

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from scipy.optimize import minimize
import statsmodels.tsa.api as smt
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib.pylab import rcParams
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import OneHotEncoder
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots    
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# %%
from testing_functions import *

# %%
begin_1 = '01-01-2016'
end_1 = '06-01-2016'
begin_2 = '06-01-2016'
end_2 = '12-31-2016'
begin_3 = '01-01-2017'
end_3 = '06-01-2017'
begin_4 = '06-01-2017'
end_4 = '12-31-2017'
begin_5 = '01-01-2018'
end_5 = '06-01-2018'
begin_6 = '06-01-2018'
end_6 = '12-31-2018'
begin_7 = '01-01-2019'
end_7 = '06-01-2019'
begin_8 = '06-01-2019'
end_8 = '12-31-2019'

# %% [markdown]
# Chunk 1

# %%
df_1 = get_nyiso_data(begin_1, end_1)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20151231pal.csv, {}
# Failed to find daily load data for 2015-12-31 but found monthly data, using that
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-17f26b8dab7d> in <module>
# ----> 1 df_1 = get_nyiso_data(begin_1, end_1)
#
# ~/Final_Project/peaky_flask/peaky-finders/notebooks/testing_functions.py in get_nyiso_data(begin, end)
#     151 def get_nyiso_data(begin, end):
#     152     nyiso = client_factory('NYISO', timeout_seconds=60)
# --> 153     df = nyiso.get_load(latest=False, yesterday=False, start_at=begin, end_at=end)
#     154     df = pd.DataFrame(df)
#     155     df = df[['load_MW', 'timestamp']]
#
# ~/anaconda3/envs/peaky_finder_env/lib/python3.7/site-packages/pyiso-0.4.0-py3.7.egg/pyiso/nyiso.py in get_load(self, latest, start_at, end_at, **kwargs)
# ...

# %%
df_1.to_csv('nyiso_load_2016.csv')

# %%
df_1 = get_features(df_1)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_1.to_csv('nyiso_load_2016.csv')

# %% [markdown]
# Chunk 2

# %%
begin_2
# Out:
# '06-01-2016'

# %%
end_2
# Out:
# '01-01-2017'

# %%
end_2 = '12-31-2016'

# %%
df_2 = get_nyiso_data(begin_2, end_2)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20160531pal.csv, {}
# Failed to find daily load data for 2016-05-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20160601pal.csv, {}
# Failed to find daily load data for 2016-06-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20160602pal.csv, {}
# Failed to find daily load data for 2016-06-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20160603pal.csv, {}
# Failed to find daily load data for 2016-06-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20160604pal.csv, {}
# Failed to find daily load data for 2016-06-04 but found monthly data, using that
# ...

# %%
df_2.head()
# Out:
#                   timestamp  load_MW
# 0 2016-05-31 23:00:00-04:00  17669.5
# 1 2016-06-01 00:00:00-04:00  17490.3
# 2 2016-06-01 01:00:00-04:00  16449.1
# 3 2016-06-01 02:00:00-04:00  15656.5
# 4 2016-06-01 03:00:00-04:00  15156.2

# %%
df_2 = get_features(df_2)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_2.to_csv('nyiso_load_2016_pt2.csv')

# %% [markdown]
# Chunk 3

# %%
df_3 = get_nyiso_data(begin_3, end_3)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20161231pal.csv, {}
# Failed to find daily load data for 2016-12-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170101pal.csv, {}
# Failed to find daily load data for 2017-01-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170102pal.csv, {}
# Failed to find daily load data for 2017-01-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170103pal.csv, {}
# Failed to find daily load data for 2017-01-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170104pal.csv, {}
# Failed to find daily load data for 2017-01-04 but found monthly data, using that
# ...

# %%
df_3 = get_features(df_3)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_3.to_csv('nyiso_load_2017_pt1.csv')

# %% [markdown]
# Chunk 4

# %%
df_4 = get_nyiso_data(begin_4, end_4)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170531pal.csv, {}
# Failed to find daily load data for 2017-05-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170601pal.csv, {}
# Failed to find daily load data for 2017-06-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170602pal.csv, {}
# Failed to find daily load data for 2017-06-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170603pal.csv, {}
# Failed to find daily load data for 2017-06-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20170604pal.csv, {}
# Failed to find daily load data for 2017-06-04 but found monthly data, using that
# ...

# %%
df_4 = get_features(df_4)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_4.to_csv('nyiso_load_2017_pt2.csv')

# %% [markdown]
# Chunk 5

# %%
df_5 = get_nyiso_data(begin_5, end_5)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20171231pal.csv, {}
# Failed to find daily load data for 2017-12-31 but found monthly data, using that
# NYISO: connection error for http://mis.nyiso.com/public/csv/pal/20180101pal.csv, {}:
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed to find daily load data for 2018-01-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180102pal.csv, {}
# Failed to find daily load data for 2018-01-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180103pal.csv, {}
# Failed to find daily load data for 2018-01-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180104pal.csv, {}
# Failed to find daily load data for 2018-01-04 but found monthly data, using that
# ...

# %%
df_5 = get_features(df_5)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_5.to_csv('nyiso_load_2018_pt1.csv')

# %% [markdown]
# Chunk 6

# %%
df_6 = get_nyiso_data(begin_6, end_6)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180531pal.csv, {}
# Failed to find daily load data for 2018-05-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180601pal.csv, {}
# Failed to find daily load data for 2018-06-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180602pal.csv, {}
# Failed to find daily load data for 2018-06-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180603pal.csv, {}
# Failed to find daily load data for 2018-06-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20180604pal.csv, {}
# Failed to find daily load data for 2018-06-04 but found monthly data, using that
# ...

# %%
df_6 = get_features(df_6)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_6.to_csv('nyiso_load_2018_pt2.csv')

# %% [markdown]
# Chunk 7

# %%
df_7 = get_nyiso_data(begin_7, end_7)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20181231pal.csv, {}
# Failed to find daily load data for 2018-12-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190101pal.csv, {}
# Failed to find daily load data for 2019-01-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190102pal.csv, {}
# Failed to find daily load data for 2019-01-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190103pal.csv, {}
# Failed to find daily load data for 2019-01-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190104pal.csv, {}
# Failed to find daily load data for 2019-01-04 but found monthly data, using that
# ...

# %%
df_7 = get_features(df_7)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_7.to_csv('nyiso_load_2019_pt1.csv')

# %% [markdown]
# Chunk 8

# %%
df_8 = get_nyiso_data(begin_8, end_8)
# Out:
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190531pal.csv, {}
# Failed to find daily load data for 2019-05-31 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190601pal.csv, {}
# Failed to find daily load data for 2019-06-01 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190602pal.csv, {}
# Failed to find daily load data for 2019-06-02 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190603pal.csv, {}
# Failed to find daily load data for 2019-06-03 but found monthly data, using that
# NYISO: request failure with code 404 for http://mis.nyiso.com/public/csv/pal/20190604pal.csv, {}
# Failed to find daily load data for 2019-06-04 but found monthly data, using that
# ...

# %%
df_8 = get_features(df_8)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
df_8.to_csv('nyiso_load_2019_pt2.csv')

# %% [markdown]
# Import and create dataframes, create ARMA features, and standardize

# %%
df_1 = pd.read_csv('nyiso_load_2016_pt1.csv')
df_2 = pd.read_csv('nyiso_load_2016_pt2.csv')
df_3 = pd.read_csv('nyiso_load_2017_pt1.csv')
df_4 = pd.read_csv('nyiso_load_2017_pt2.csv')
df_5 = pd.read_csv('nyiso_load_2018_pt1.csv')
df_6 = pd.read_csv('nyiso_load_2018_pt2.csv')
df_7 = pd.read_csv('nyiso_load_2019_pt1.csv')
df_8 = pd.read_csv('nyiso_load_2019_pt2.csv')

# %%
df_2016 = [df_1, df_2]
df_2017 = [df_3, df_4]
df_2018 = [df_5, df_6]
df_2019 = [df_7, df_8]

# %%
df_2016 = pd.concat(df_2016)
df_2017 = pd.concat(df_2017)
df_2018 = pd.concat(df_2018)
df_2019 = pd.concat(df_2019)

# %%
df_2016 = prep_V5(df_2016)
df_2017 = prep_V5(df_2017)
df_2018 = prep_V5(df_2018)
df_2019 = prep_V5(df_2019)

# %%
df_total = [df_2016, df_2017, df_2018, df_2019]

# %%
df_total = pd.concat(df_total)

# %%
df_total = prep_nyiso_data(df_total)

# %%
df_total.head()
# Out:
#                     timestamp  load_MW  temperature  humidity  cloudcover  \
# 47  2016-01-02 22:00:00-05:00  17752.3    -1.241511      0.63        0.00
# 48  2016-01-02 23:00:00-05:00  16797.6    -1.299398      0.67        0.00
# 49  2016-01-03 00:00:00-05:00  15819.0    -1.243737      0.66        0.00
# 50  2016-01-03 01:00:00-05:00  14888.8    -1.273238      0.69        0.00
# 51  2016-01-03 02:00:00-05:00  14304.0    -1.282143      0.70        0.25
#
#     uvindex  load (t-24)  first seasonal difference  prev-day-hour-Std  \
# 47      0.0    -0.269747                  -1.045884          -0.520014
# 48      0.0    -0.549291                  -1.297657          -0.529226
# 49      0.0    -0.839847                  -1.348781          -0.528227
# 50      0.0    -1.092337                  -1.172045          -0.521134
# 51      0.0    -1.229178                  -0.635103          -0.520488
#
#     prev-day-hour-MA  ...  hour_15.0  hour_16.0  hour_17.0  hour_18.0  \
# ...

# %% [markdown]
# Train test split, run model

# %%
from sklearn.model_selection import train_test_split

# %%
df_total = df_total.set_index('timestamp')

# %%
y = df_total['load_MW']
X = df_total.drop('load_MW', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import xgboost as xgb

# %%
reg = xgb.XGBRegressor()
reg.fit(X_train, y_train)
training_preds = reg.predict(X_train)
val_preds = reg.predict(X_test)
# Out:
# [15:34:08] WARNING: /usr/local/miniconda/conda-bld/xgboost_1572315027083/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('Mean Absolute Error:', mean_absolute_error(y_test, val_preds))  
print('Mean Squared Error:', mean_squared_error(y_test, val_preds))  
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, val_preds)))
# Out:
# Mean Absolute Error: 565.0593519782428
# Mean Squared Error: 563371.2694546747
# Root Mean Squared Error: 750.5806215555226

# %% [markdown]
# Significant improvement in RMSE.

# %%
import pickle
file_name = 'xg_boost_load_modelV3.pkl'
pickle.dump(reg, open(file_name, "wb"))
